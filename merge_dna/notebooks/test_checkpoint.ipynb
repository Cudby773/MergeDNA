# %%
import torch

# %%
path = "../../checkpoints/step_0001000.pt"
device = torch.device("cuda")
ckpt = torch.load(path, map_location=device)

# %%
ckpt["model"]['local_encoder.layers.0.token_merge._pos_a']
# Out:
# tensor([ 0,  2,  4,  6,  8, 10, 12, 14], device='cuda:0')
